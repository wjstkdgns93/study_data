# %% [markdown]
# #### msit : 과학기술 정보통신부
# - https://msit.go.kr
# - 보도자료를 크롤링
# - json으로 데이터 수집
# - json 데이터 안에 html 코드가 들어있습니다.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
page = 1
url = "https://www.msit.go.kr/dynamic/article/mssw311?\
&sort=operday=desc&below=false&pageout=true&aradon.result.format=json\
&aradon.page.pageNo={}&aradon.page.listNum=10&aradon.page.screenCount=5\
&aradon.referrer.href=https://msit.go.kr/web/msipContents/contents.do?mId=NzI="\
.format(page)

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
datas = response.json()["result"]["nodes"]
columns = ["action", "admin_p", "artid", "artsubject", "artcont"]
msit_df = pd.DataFrame(datas)[columns]
msit_df.tail(2)
# Out:
#   action           admin_p    artid  \
# 8    INS           기후환경대응팀  2505058
# 9    MOD  정보통신정책과, 네트워크정책과  2505057
#
#                                       artsubject  \
# 8  수소 기술개발 등 기후변화 대응을 위한 기후·환경 연구개발에 1,340억 원 투자
# 9                   디지털혁신 3대 범정부 태스크포스(TF) 구성·운영
#
#                                              artcont
# 8  <font size="3"></font>\r\n<p align="center" st...
# 9  <p align="center" style="margin: 0px; text-ali...

# %%
msit_df["artcont"][0]
# Out:
# '<p align="center" style="margin: 0px; text-align: center; line-height: 115%; vertical-align: baseline; -ms-layout-grid-mode: char; -ms-word-break: keep-all;"><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 20pt;">2019</span><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 20pt;">년 </span><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 20pt;">정보통신기술 수출 1,769억불, 수입 1,084억불</span></p>\r\n<p style="margin: 0px; line-height: 115%; -ms-word-break: keep-all;"><span style="font-family: 맑은 고딕;">&nbsp;</span></p>\r\n<p align="left" style="margin: 0px; text-align: left; line-height: 115%; vertical-align: baseline; -ms-word-break: keep-all;"><b><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 12pt;">1. 2019</span></b><b><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 12pt;">년 실적 및 특징</span></b></p>\r\n<p align="left" style="margin: 0px; text-align: left; line-height: 115%; vertical-align: baseline; -ms-word-break: keep-all;"><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 12pt;">&nbsp;</span></p>\r\n<p style="margin: 0px; line-height: 115%; vertical-align: baseline; -ms-layout-grid-mode: char; -ms-word-break: keep-all;"><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 12pt;">□ &rsquo;19년\r\n정보통신기술</span><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 11pt;">(</span><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 11pt;">이하 &rsquo;<b>ICT&lsquo;</b>)</span><b><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 12pt;"> </span></b><b><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 12pt;">수출</span></b><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 12pt;">은 <b>1,769억불</b>, <b>수입</b>은<b> 1,084억불</b>, <b>수지</b>는 <b>685억불 흑자</b>로 잠정 집계</span></p>\r\n<p style="margin: 0px; line-height: 115%; vertical-align: baseline; -ms-layout-grid-mode: char; -ms-word-break: keep-all;"><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 8pt;">&nbsp;</span></p>\r\n<p style="margin: 0px; line-height: 115%; vertical-align: baseline; -ms-layout-grid-mode: char; -ms-word-break: keep-all;"><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 12pt;">ㅇ <b>수출</b>은 <b>주력 품목\r\n시장 정체</b> 및 <b>중국</b> 등 <b>글로벌</b> 전반의 <b>경기 둔화, 기저효과 </b>등으로<b>19.7% 감소</b>하였으나, <b>수출액</b>은<b>역대 3위 기록</b></span></p>\r\n<p style="margin: 0px; line-height: 115%; vertical-align: baseline; -ms-layout-grid-mode: char; -ms-word-break: keep-all;"><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 11pt;">※ ICT 연간 수출 Top3(억불) :\r\n(1위:&rsquo;18년)2,204, (2위:&rsquo;17년)1,976, (3위:&rsquo;19년)1,769</span></p>\r\n<p style="margin: 0px; line-height: 115%; vertical-align: baseline; -ms-layout-grid-mode: char; -ms-word-break: keep-all;"><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 11pt;">※ 분기별 추이(억불) : (&rsquo;19. 1Q)\r\n429.3(△17.9%) &rarr; (2Q) 443.0(△18.9%) &rarr; (3Q) 454.6(△22.9%) &rarr; (4Q) 442.0(△18.7%)</span></p>\r\n<p style="margin: 0px; line-height: 115%; vertical-align: baseline; -ms-layout-grid-mode: char; -ms-word-break: keep-all;"><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 8pt;">&nbsp;</span></p>\r\n<p style="margin: 0px; line-height: 115%; vertical-align: baseline; -ms-layout-grid-mode: char; -ms-word-break: keep-all;"><b><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 12pt;">ㅇ 품목별로는 반도체</span></b><b><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 11pt;">(951.6</span></b><b><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 11pt;">억불, △25.7%), </span></b><b><span style="color: black; line-height: 115%; font-family: 맑은 고딕; font-size: 12pt;" ...

# %%
def html_to_text(html):
    remove_words = ["\n", "\xa0", "□", "\r"]
    content = BeautifulSoup(html, "html.parser").text
    for remove_word in remove_words:
        content = content.replace(remove_word, "")
    return content

# %%
content = html_to_text(msit_df["artcont"][1])
content[:100]
# Out:
# '최기영 과기정통부 장관, 설 명절 민생현장 방문- 설 우편물 소통현황 점검 및 공주산성시장·사회복지시설 방문 - 과학기술정보통신부 최기영 장관은 1월20일(월) 오전 서청주우체국('

# %%
msit_df["artcont"] = msit_df["artcont"].apply(html_to_text)
msit_df.tail(2)
# Out:
#   action      admin_p    artid                       artsubject  \
# 8    MOD  구주아프리카협력담당관  2296332  과기정통부, 스페인 산업연결 4.0 컨퍼런스 주빈국 참여
# 9    INS    지역과학기술진흥과  2295930       ’20년 상반기 강소특구 지정을 위한 심사 개시
#
#                                              artcont
# 8  산업의 디지털 변혁, 한-스페인 협력강화- 과기정통부, 스페인 “산업연결 4.0 컨...
# 9  ’20년 상반기 강소특구지정을 위한 심사 개시- 7개 시·도에서 강소특구 지정 요청...
