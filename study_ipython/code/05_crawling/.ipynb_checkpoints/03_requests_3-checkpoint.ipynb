# %% [markdown]
# ### 직방
# - 동이름을 입력하면 아파트 매물을 데이터 프레임으로 만들기
# - robots.txt

# %% [markdown]
# #### 1. 웹서비스 분석 : URL 찾기, 크롤링 전략 세우기
#
# - 동이름 입력 -> lat, lng
# - lat, lng -> geohash : geohash 패키지 설치
# - geohash -> item ids
# - item ids -> item datas(데이터 프레임)

# %%
import requests
# 동이름 -> 위도 경도
addr = "성수동"
url = "https://apis.zigbang.com/search?q={}".format(addr)
response = requests.get(url)
data = response.json()["items"][0]
lat, lng = data["lat"], data["lng"]
lat, lng
# Out:
# (37.541725158691406, 127.04335021972656)

# %%
# 위도, 경도 -> geohash
# pip install geohash2

# %%
import geohash2

# %%
# precision : 작을수록 큰범위, 클수록 작은 범위
geohash = geohash2.encode(lat, lng, precision=5)
lat, lng, geohash
# Out:
# (37.541725158691406, 127.04335021972656, 'wydmd')

# %%
# geohash -> ids
url = "https://apis.zigbang.com/property/apartments/items?\
domain=zigbang&geohash={}\
&q=type=sales%7Cprice=0~-1%7CfloorArea=0~-1".format(geohash)
response = requests.get(url)
datas = response.json()["items"]
ids = [data["itemId"] for data in datas]
len(ids), ids[:3]
# Out:
# (1584, [18729239, 17196255, 17905774])

# %%
# ids -> items
ids_str = str(ids[:200]).replace(" ", "")
url = "https://apis.zigbang.com/property/apartments/items?\
vritemIds={ids}&itemIds={ids}&citemIds={ids}".format(ids=ids_str)
response = requests.get(url)
datas = response.json()["items"]
datas
# Out:
# [{'itemId': 18729239,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,완전특올수리된집,실제6층높이,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:41.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '301동',
#   'roomTypeId': 7053,
#   'grossAreaName': {'m2': 141, 'p': 42},
#   'grossArea': {'m2': 141, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7053/5216716d33334f3cbe82f04d43c288d0.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-11-02 18:40:11',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7053/5216716d33334f3cbe82f04d43c288d0.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 141, 'p': 42},
#   'isNew': True,
#   'sales': 90000},
#  {'itemId': 17196255,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '12',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,엄청 밝고 깨끗한집.정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:41.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '104동',
#   'roomTypeId': 43503,
#   'grossAreaName': {'m2': 143, 'p': 43},
#   'grossArea': {'m2': 143, 'p': 43},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 116, 'p': 35},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43503/628a7b8783f24a9e91ac98b937e41a17.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-07-16 17:30:03',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43503/628a7b8783f24a9e91ac98b937e41a17.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 143, 'p': 43},
#   'isNew': True,
#   'sales': 98000},
#  {'itemId': 17905774,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '12',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,수리되어 깨끗한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:41.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '102동',
#   'roomTypeId': 43499,
#   'grossAreaName': {'m2': '109A', 'p': '32A'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43499/23faf7cd6ea14a548684449078372f36.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-09-04 17:44:03',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43499/23faf7cd6ea14a548684449078372f36.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '109A', 'p': '32A'},
#   'isNew': True,
#   'sales': 88000},
#  {'itemId': 18255266,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '12',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,수리되어 깨끗한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:41.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '104동',
#   'roomTypeId': 43503,
#   'grossAreaName': {'m2': 143, 'p': 43},
#   'grossArea': {'m2': 143, 'p': 43},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 116, 'p': 35},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43503/628a7b8783f24a9e91ac98b937e41a17.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-10-01 18:20:44',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43503/628a7b8783f24a9e91ac98b937e41a17.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 143, 'p': 43},
#   'isNew': True,
#   'sales': 88000},
#  {'itemId': 18313692,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리되어 깨끗한집, 앞조망,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:41.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '103동',
#   'roomTypeId': 43499,
#   'grossAreaName': {'m2': '109A', 'p': '32A'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43499/23faf7cd6ea14a548684449078372f36.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-10-05 14:15:57',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43499/23faf7cd6ea14a548684449078372f36.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '109A', 'p': '32A'},
#   'isNew': True,
#   'sales': 88000},
#  {'itemId': 18357389,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '12',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,앞조망,엄청 밝고 깨끗한집.정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:41.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '102동',
#   'roomTypeId': 43499,
#   'grossAreaName': {'m2': '109A', 'p': '32A'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43499/23faf7cd6ea14a548684449078372f36.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-10-08 18:21:03',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43499/23faf7cd6ea14a548684449078372f36.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '109A', 'p': '32A'},
#   'isNew': True,
#   'sales': 90000},
#  {'itemId': 18585960,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '12',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,밝고수리되어 깨끗한집.정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:41.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '104동',
#   'roomTypeId': 43503,
#   'grossAreaName': {'m2': 143, 'p': 43},
#   'grossArea': {'m2': 143, 'p': 43},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 116, 'p': 35},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43503/628a7b8783f24a9e91ac98b937e41a17.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-10-24 15:38:02',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43503/628a7b8783f24a9e91ac98b937e41a17.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 143, 'p': 43},
#   'isNew': True,
#   'sales': 100000},
#  {'itemId': 18658413,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입주시 올리모델링,깨끗함,특올수리',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:41.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '103동',
#   'roomTypeId': 43500,
#   'grossAreaName': {'m2': '109B', 'p': '32B'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-10-29 17:38:19',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '109B', 'p': '32B'},
#   'isNew': True,
#   'sales': 90000},
#  {'itemId': 18688865,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '14',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,밝고 깨끗한집.세안고',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:41.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '101동',
#   'roomTypeId': 43499,
#   'grossAreaName': {'m2': '109A', 'p': '32A'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43499/23faf7cd6ea14a548684449078372f36.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-10-31 16:14:37',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43499/23faf7cd6ea14a548684449078372f36.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '109A', 'p': '32A'},
#   'isNew': True,
#   'sales': 86000},
#  {'itemId': 18767751,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리되어 깨끗한집,정상입주,급매물',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:41.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '103동',
#   'roomTypeId': 43499,
#   'grossAreaName': {'m2': '109A', 'p': '32A'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43499/23faf7cd6ea14a548684449078372f36.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-11-05 15:40:26',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43499/23faf7cd6ea14a548684449078372f36.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '109A', 'p': '32A'},
#   'isNew': True,
#   'sales': 86000},
#  {'itemId': 18882926,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,깨끗한집.로얄층.정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:41.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '103동',
#   'roomTypeId': 43499,
#   'grossAreaName': {'m2': '109A', 'p': '32A'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43499/23faf7cd6ea14a548684449078372f36.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-11-12 18:32:26',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43499/23faf7cd6ea14a548684449078372f36.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '109A', 'p': '32A'},
#   'isNew': True,
#   'sales': 88000},
#  {'itemId': 19200320,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '특올수리된집,밝고 환한집,세안고매매',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '305동',
#   'roomTypeId': 7055,
#   'grossAreaName': {'m2': 86, 'p': 26},
#   'grossArea': {'m2': 86, 'p': 26},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7055/4ae5539e674b4340b9f8e588e3c2e491.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-03 14:25:23',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7055/4ae5539e674b4340b9f8e588e3c2e491.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 86, 'p': 26},
#   'isNew': True,
#   'sales': 70000},
#  {'itemId': 19254316,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,깨끗한집 ,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '111동',
#   'roomTypeId': 7053,
#   'grossAreaName': {'m2': 141, 'p': 42},
#   'grossArea': {'m2': 141, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7053/5216716d33334f3cbe82f04d43c288d0.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-06 11:36:51',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7053/5216716d33334f3cbe82f04d43c288d0.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 141, 'p': 42},
#   'isNew': True,
#   'sales': 87000},
#  {'itemId': 19361085,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,깨끗한집,앞조망,세안고매매',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '111동',
#   'roomTypeId': 7053,
#   'grossAreaName': {'m2': 141, 'p': 42},
#   'grossArea': {'m2': 141, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7053/5216716d33334f3cbe82f04d43c288d0.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-12 16:29:35',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7053/5216716d33334f3cbe82f04d43c288d0.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 141, 'p': 42},
#   'isNew': True,
#   'sales': 95000},
#  {'itemId': 19369589,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,수리되어 깨끗한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '111동',
#   'roomTypeId': 7053,
#   'grossAreaName': {'m2': 141, 'p': 42},
#   'grossArea': {'m2': 141, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7053/5216716d33334f3cbe82f04d43c288d0.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-13 10:54:30',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7053/5216716d33334f3cbe82f04d43c288d0.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 141, 'p': 42},
#   'isNew': True,
#   'sales': 85000},
#  {'itemId': 19438655,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리되어 깨끗한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '305동',
#   'roomTypeId': 7055,
#   'grossAreaName': {'m2': 86, 'p': 26},
#   'grossArea': {'m2': 86, 'p': 26},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7055/4ae5539e674b4340b9f8e588e3c2e491.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-17 18:54:35',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7055/4ae5539e674b4340b9f8e588e3c2e491.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 86, 'p': 26},
#   'isNew': True,
#   'sales': 71000},
#  {'itemId': 19438709,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리되어 깨끗한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '305동',
#   'roomTypeId': 7055,
#   'grossAreaName': {'m2': 86, 'p': 26},
#   'grossArea': {'m2': 86, 'p': 26},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7055/4ae5539e674b4340b9f8e588e3c2e491.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-17 18:56:57',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7055/4ae5539e674b4340b9f8e588e3c2e491.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 86, 'p': 26},
#   'isNew': True,
#   'sales': 71000},
#  {'itemId': 19533648,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리되어 깨끗한집,정상입주,급매물',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '110동',
#   'roomTypeId': 7055,
#   'grossAreaName': {'m2': 86, 'p': 26},
#   'grossArea': {'m2': 86, 'p': 26},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7055/4ae5539e674b4340b9f8e588e3c2e491.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-24 10:23:23',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7055/4ae5539e674b4340b9f8e588e3c2e491.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 86, 'p': 26},
#   'isNew': True,
#   'sales': 65000},
#  {'itemId': 19533729,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '16',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리되어 꺠끗한집,공원조망,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '101동',
#   'roomTypeId': 7051,
#   'grossAreaName': {'m2': '108A', 'p': '32A'},
#   'grossArea': {'m2': 108, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7051/c3ad96cb2b3a44d7bc6e457cd9a778a3.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-24 10:25:52',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7051/c3ad96cb2b3a44d7bc6e457cd9a778a3.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '108A', 'p': '32A'},
#   'isNew': True,
#   'sales': 85000},
#  {'itemId': 19569939,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리되어 깨끗한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '202동',
#   'roomTypeId': 7051,
#   'grossAreaName': {'m2': '108A', 'p': '32A'},
#   'grossArea': {'m2': 108, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7051/c3ad96cb2b3a44d7bc6e457cd9a778a3.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-26 17:00:15',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7051/c3ad96cb2b3a44d7bc6e457cd9a778a3.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '108A', 'p': '32A'},
#   'isNew': True,
#   'sales': 85000},
#  {'itemId': 19752302,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,깨끗한집.앞조망,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '303동',
#   'roomTypeId': 7051,
#   'grossAreaName': {'m2': '108A', 'p': '32A'},
#   'grossArea': {'m2': 108, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7051/c3ad96cb2b3a44d7bc6e457cd9a778a3.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2020-01-07 10:28:53',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7051/c3ad96cb2b3a44d7bc6e457cd9a778a3.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '108A', 'p': '32A'},
#   'isNew': True,
#   'sales': 87000},
#  {'itemId': 19819242,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,올수리된집,강조망,세안고',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '201동',
#   'roomTypeId': 7051,
#   'grossAreaName': {'m2': '108A', 'p': '32A'},
#   'grossArea': {'m2': 108, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7051/c3ad96cb2b3a44d7bc6e457cd9a778a3.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2020-01-10 11:35:10',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7051/c3ad96cb2b3a44d7bc6e457cd9a778a3.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '108A', 'p': '32A'},
#   'isNew': True,
#   'sales': 93000},
#  {'itemId': 19841298,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55245581191043,
#   'lng': 127.02671689836149,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '로얄동 로얄층 정상입주되는 급매물',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 3956,
#   'apartmentName': '벽산',
#   'buildingName': '305동',
#   'roomTypeId': 7055,
#   'grossAreaName': {'m2': 86, 'p': 26},
#   'grossArea': {'m2': 86, 'p': 26},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/3956/7055/4ae5539e674b4340b9f8e588e3c2e491.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2020-01-11 13:20:24',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/3956/7055/4ae5539e674b4340b9f8e588e3c2e491.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 86, 'p': 26},
#   'isNew': True,
#   'sales': 72000},
#  {'itemId': 19243605,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54910034615845,
#   'lng': 127.02736299736137,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '올수리된집,정상입주,급매물',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 5646,
#   'apartmentName': '금호삼성래미안',
#   'buildingName': '102동',
#   'roomTypeId': 8957,
#   'grossAreaName': {'m2': 105, 'p': 31},
#   'grossArea': {'m2': 105, 'p': 31},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/5646/8957/e5205683ee85404aa38ed32060a804d1.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-05 16:11:45',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/5646/8957/e5205683ee85404aa38ed32060a804d1.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 105, 'p': 31},
#   'isNew': True,
#   'sales': 87000},
#  {'itemId': 19324308,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54910034615845,
#   'lng': 127.02736299736137,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '올수리된집,밝고 환한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 5646,
#   'apartmentName': '금호삼성래미안',
#   'buildingName': '104동',
#   'roomTypeId': 8957,
#   'grossAreaName': {'m2': 105, 'p': 31},
#   'grossArea': {'m2': 105, 'p': 31},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/5646/8957/e5205683ee85404aa38ed32060a804d1.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-10 17:16:21',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/5646/8957/e5205683ee85404aa38ed32060a804d1.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 105, 'p': 31},
#   'isNew': True,
#   'sales': 92000},
#  {'itemId': 19360967,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54910034615845,
#   'lng': 127.02736299736137,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리되어 깨끗한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 5646,
#   'apartmentName': '금호삼성래미안',
#   'buildingName': '104동',
#   'roomTypeId': 8957,
#   'grossAreaName': {'m2': 105, 'p': 31},
#   'grossArea': {'m2': 105, 'p': 31},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/5646/8957/e5205683ee85404aa38ed32060a804d1.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-12 16:26:14',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/5646/8957/e5205683ee85404aa38ed32060a804d1.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 105, 'p': 31},
#   'isNew': True,
#   'sales': 95000},
#  {'itemId': 19637747,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54910034615845,
#   'lng': 127.02736299736137,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리되어 깨끗한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 5646,
#   'apartmentName': '금호삼성래미안',
#   'buildingName': '104동',
#   'roomTypeId': 8957,
#   'grossAreaName': {'m2': 105, 'p': 31},
#   'grossArea': {'m2': 105, 'p': 31},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/5646/8957/e5205683ee85404aa38ed32060a804d1.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-31 14:35:40',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/5646/8957/e5205683ee85404aa38ed32060a804d1.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 105, 'p': 31},
#   'isNew': True,
#   'sales': 95000},
#  {'itemId': 19637944,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54910034615845,
#   'lng': 127.02736299736137,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '올수리된집,밝고 환한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 5646,
#   'apartmentName': '금호삼성래미안',
#   'buildingName': '201동',
#   'roomTypeId': 8957,
#   'grossAreaName': {'m2': 105, 'p': 31},
#   'grossArea': {'m2': 105, 'p': 31},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/5646/8957/e5205683ee85404aa38ed32060a804d1.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-31 14:43:17',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/5646/8957/e5205683ee85404aa38ed32060a804d1.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 105, 'p': 31},
#   'isNew': True,
#   'sales': 93000},
#  {'itemId': 19637981,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.54910034615845,
#   'lng': 127.02736299736137,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리되어 깨끗한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 5646,
#   'apartmentName': '금호삼성래미안',
#   'buildingName': '101동',
#   'roomTypeId': 8958,
#   'grossAreaName': {'m2': 138, 'p': 41},
#   'grossArea': {'m2': 138, 'p': 41},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/5646/8958/db58f2808c584ef0a87fa643df9506ef.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-31 14:44:53',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/5646/8958/db58f2808c584ef0a87fa643df9506ef.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 138, 'p': 41},
#   'isNew': True,
#   'sales': 110000},
#  {'itemId': 19438979,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '수리되어 깨끗한집, 앞조망,귀한매매,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '103동',
#   'roomTypeId': 43497,
#   'grossAreaName': {'m2': '79A', 'p': '23A'},
#   'grossArea': {'m2': 79, 'p': 23},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43497/80abc0f132ec4b8aa8f69bc31238f81a.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-17 19:11:33',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43497/80abc0f132ec4b8aa8f69bc31238f81a.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '79A', 'p': '23A'},
#   'isNew': True,
#   'sales': 78000},
#  {'itemId': 19569756,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,엄청 밝고 깨끗한집.정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '103동',
#   'roomTypeId': 43500,
#   'grossAreaName': {'m2': '109B', 'p': '32B'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-26 16:54:04',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '109B', 'p': '32B'},
#   'isNew': True,
#   'sales': 87000},
#  {'itemId': 19569827,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '14',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,올수리된집.앞조망,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '101동',
#   'roomTypeId': 43500,
#   'grossAreaName': {'m2': '109B', 'p': '32B'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-26 16:56:45',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '109B', 'p': '32B'},
#   'isNew': True,
#   'sales': 92000},
#  {'itemId': 19638103,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '14',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,깨끗한집 .정상입주,급매물',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '101동',
#   'roomTypeId': 43500,
#   'grossAreaName': {'m2': '109B', 'p': '32B'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2019-12-31 14:49:02',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '109B', 'p': '32B'},
#   'isNew': True,
#   'sales': 82000},
#  {'itemId': 19811742,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '올수리된집,정상입주,급매물',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '103동',
#   'roomTypeId': 43500,
#   'grossAreaName': {'m2': '109B', 'p': '32B'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2020-01-09 18:35:53',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '109B', 'p': '32B'},
#   'isNew': True,
#   'sales': 88000},
#  {'itemId': 19841442,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,수리되어 깨끗한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '103동',
#   'roomTypeId': 43500,
#   'grossAreaName': {'m2': '109B', 'p': '32B'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2020-01-11 13:28:54',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '109B', 'p': '32B'},
#   'isNew': True,
#   'sales': 91000},
#  {'itemId': 19893669,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.555967012809646,
#   'lng': 127.02231794121602,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,수리되어 깨끗한집,정상입주',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:52:40.000Z',
#   'apartmentId': 11010,
#   'apartmentName': '신금호두산위브',
#   'buildingName': '103동',
#   'roomTypeId': 43500,
#   'grossAreaName': {'m2': '109B', 'p': '32B'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png',
#   'userNo': 3937218,
#   'agentId': 3937218,
#   'agentName': '스마일(단지내)공인중개사',
#   'agentTel': '0233955500',
#   'agentUserName': '이동호',
#   'agentPhone': '01084435500',
#   'created_at': '2020-01-14 15:47:35',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/11010/43500/d0218181a31b45b195416bd5926ce0d2.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '109B', 'p': '32B'},
#   'isNew': True,
#   'sales': 89000},
#  {'itemId': 19129505,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5466768,
#   'lng': 127.026643,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '올확장 시스템에어컨 신규아파트',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:47:52.000Z',
#   'apartmentId': 37269,
#   'apartmentName': '힐스테이트서울숲리버',
#   'buildingName': '102동',
#   'roomTypeId': 153557,
#   'grossAreaName': {'m2': '81A', 'p': '24A'},
#   'grossArea': {'m2': 81, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/37269/153557/1a72378405174efc8c5b6eda2ba1422e.png',
#   'userNo': 5430281,
#   'agentId': 5430281,
#   'agentName': '푸르지오공인중개사무소',
#   'agentTel': '0222996100',
#   'agentUserName': '이현정',
#   'agentPhone': '01066955579',
#   'created_at': '2019-11-28 18:18:51',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/37269/153557/1a72378405174efc8c5b6eda2ba1422e.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '81A', 'p': '24A'},
#   'isNew': True,
#   'sales': 135000},
#  {'itemId': 17953825,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '21',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55593318683651,
#   'lng': 127.02874621948274,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '행당역세권  올확장 올수리 산조망좋음 조용한동',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:43:07.000Z',
#   'apartmentId': 1349,
#   'apartmentName': '행당한진타운',
#   'buildingName': '119동',
#   'roomTypeId': 3668,
#   'grossAreaName': {'m2': 144, 'p': 43},
#   'grossArea': {'m2': 144, 'p': 43},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/1349/3668/5415046b966542c4947a2c48884decc8.png',
#   'userNo': 5582535,
#   'agentId': 5582535,
#   'agentName': '우정공인중개사사무소',
#   'agentTel': '0222957770',
#   'agentUserName': '이화정',
#   'agentPhone': '01062544876',
#   'created_at': '2019-09-09 10:18:40',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/1349/3668/5415046b966542c4947a2c48884decc8.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 144, 'p': 43},
#   'isNew': True,
#   'sales': 104000},
#  {'itemId': 18781752,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '19',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55593318683651,
#   'lng': 127.02874621948274,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '씽크대교체,도배새로함, 베란다탄성코트하여 깨긋합니다',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:43:07.000Z',
#   'apartmentId': 1349,
#   'apartmentName': '행당한진타운',
#   'buildingName': '121동',
#   'roomTypeId': 3668,
#   'grossAreaName': {'m2': 144, 'p': 43},
#   'grossArea': {'m2': 144, 'p': 43},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/1349/3668/5415046b966542c4947a2c48884decc8.png',
#   'userNo': 5582535,
#   'agentId': 5582535,
#   'agentName': '우정공인중개사사무소',
#   'agentTel': '0222957770',
#   'agentUserName': '이화정',
#   'agentPhone': '01062544876',
#   'created_at': '2019-11-06 12:59:33',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/1349/3668/5415046b966542c4947a2c48884decc8.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 144, 'p': 43},
#   'isNew': True,
#   'sales': 105000},
#  {'itemId': 18798991,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '22',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55593318683651,
#   'lng': 127.02874621948274,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '추천 행당역세권 입구동 작은방확장 올수리 ',
#   'agentNo': None,
#   'regDate': '2020-01-16',
#   'regTime': '2020-01-16T00:43:07.000Z',
#   'apartmentId': 1349,
#   'apartmentName': '행당한진타운',
#   'buildingName': '102동',
#   'roomTypeId': 3667,
#   'grossAreaName': {'m2': 108, 'p': 32},
# ...
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 137, 'p': 41},
#   'isNew': True,
#   'sales': 105000},
#  {'itemId': 19900853,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '전세끼고 매매, 초역세권, 탁트인 전망 굿, 확장형',
#   'agentNo': 47136,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T05:11:11.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '118동',
#   'roomTypeId': 149707,
#   'grossAreaName': {'m2': '111A', 'p': '33A'},
#   'grossArea': {'m2': 111, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149707/512a6f64917444fbaa8e804b442ec8d0.png',
#   'userNo': 5520475,
#   'agentId': 5520475,
#   'agentName': '투미공인중개사사무소',
#   'agentTel': '0222957777',
#   'agentUserName': '김제경',
#   'agentPhone': '01072564474',
#   'created_at': '2020-01-14 18:55:27',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149707/512a6f64917444fbaa8e804b442ec8d0.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '111A', 'p': '33A'},
#   'isNew': True,
#   'sales': 145000},
#  {'itemId': 19900926,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '전세끼고 매매,상왕십리역3분,확트인 전망,확장형',
#   'agentNo': 47136,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T05:11:08.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '102동',
#   'roomTypeId': 19806,
#   'grossAreaName': {'m2': '107A', 'p': '32A'},
#   'grossArea': {'m2': 107, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19806/1c975796072c4562b7fd24b48bde709f.png',
#   'userNo': 5520475,
#   'agentId': 5520475,
#   'agentName': '투미공인중개사사무소',
#   'agentTel': '0222957777',
#   'agentUserName': '김제경',
#   'agentPhone': '01072564474',
#   'created_at': '2020-01-14 18:58:21',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19806/1c975796072c4562b7fd24b48bde709f.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '107A', 'p': '32A'},
#   'isNew': True,
#   'sales': 137000},
#  {'itemId': 19900532,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '12',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.57046508789063,
#   'lng': 127.02467346191406,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '텐즈힐 판상형 급매,입주가능,갭5,5억',
#   'agentNo': None,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T03:59:56.000Z',
#   'apartmentId': 22637,
#   'apartmentName': '텐즈힐2단지',
#   'buildingName': '209동',
#   'roomTypeId': 19225,
#   'grossAreaName': {'m2': 109, 'p': 32},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/22637/19225/e875ae5b098e4ada9221c18892e83553.png',
#   'userNo': 6025584,
#   'agentId': 6025584,
#   'agentName': '금맥공인중개사사무소',
#   'agentTel': '0327522442',
#   'agentUserName': '최효주',
#   'agentPhone': '01026335167',
#   'created_at': '2020-01-14 18:45:08',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/22637/19225/e875ae5b098e4ada9221c18892e83553.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 109, 'p': 32},
#   'isNew': True,
#   'sales': 130000},
#  {'itemId': 19899722,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '33p 인테리어,조망좋은 조용한 라인,갭투자추천',
#   'agentNo': None,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T03:59:49.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '103동',
#   'roomTypeId': 149707,
#   'grossAreaName': {'m2': '111A', 'p': '33A'},
#   'grossArea': {'m2': 111, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149707/512a6f64917444fbaa8e804b442ec8d0.png',
#   'userNo': 6025584,
#   'agentId': 6025584,
#   'agentName': '금맥공인중개사사무소',
#   'agentTel': '0327522442',
#   'agentUserName': '최효주',
#   'agentPhone': '01026335167',
#   'created_at': '2020-01-14 18:25:41',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149707/512a6f64917444fbaa8e804b442ec8d0.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '111A', 'p': '33A'},
#   'isNew': True,
#   'sales': 145000},
#  {'itemId': 19899986,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.57046508789063,
#   'lng': 127.02467346191406,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '32p 양창형구조,세안고 투자,조용한 라인',
#   'agentNo': None,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T03:59:46.000Z',
#   'apartmentId': 22637,
#   'apartmentName': '텐즈힐2단지',
#   'buildingName': '202동',
#   'roomTypeId': 19223,
#   'grossAreaName': {'m2': 106, 'p': 32},
#   'grossArea': {'m2': 106, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/22637/19223/80fcabaf6e8946df977fe51d15d4137a.png',
#   'userNo': 6025584,
#   'agentId': 6025584,
#   'agentName': '금맥공인중개사사무소',
#   'agentTel': '0327522442',
#   'agentUserName': '최효주',
#   'agentPhone': '01026335167',
#   'created_at': '2020-01-14 18:31:41',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/22637/19223/80fcabaf6e8946df977fe51d15d4137a.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 106, 'p': 32},
#   'isNew': True,
#   'sales': 136000},
#  {'itemId': 19895915,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '8',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '판상형,입주매물,확장',
#   'agentNo': None,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T03:59:43.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '111동',
#   'roomTypeId': 149694,
#   'grossAreaName': {'m2': '78A', 'p': '23A'},
#   'grossArea': {'m2': 78, 'p': 23},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149694/9db2c9d2bbf84addb6ee6f8cded64939.png',
#   'userNo': 6025584,
#   'agentId': 6025584,
#   'agentName': '금맥공인중개사사무소',
#   'agentTel': '0327522442',
#   'agentUserName': '최효주',
#   'agentPhone': '01026335167',
#   'created_at': '2020-01-14 16:48:16',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149694/9db2c9d2bbf84addb6ee6f8cded64939.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '78A', 'p': '23A'},
#   'isNew': True,
#   'sales': 120000},
#  {'itemId': 19900656,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '12',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.57046508789063,
#   'lng': 127.02467346191406,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '초급매,월세안고 투자추천,판상형',
#   'agentNo': None,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T03:59:41.000Z',
#   'apartmentId': 22637,
#   'apartmentName': '텐즈힐2단지',
#   'buildingName': '209동',
#   'roomTypeId': 19225,
#   'grossAreaName': {'m2': 109, 'p': 32},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/22637/19225/e875ae5b098e4ada9221c18892e83553.png',
#   'userNo': 6025584,
#   'agentId': 6025584,
#   'agentName': '금맥공인중개사사무소',
#   'agentTel': '0327522442',
#   'agentUserName': '최효주',
#   'agentPhone': '01026335167',
#   'created_at': '2020-01-14 18:48:03',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/22637/19225/e875ae5b098e4ada9221c18892e83553.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 109, 'p': 32},
#   'isNew': True,
#   'sales': 120000},
#  {'itemId': 19900712,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '7',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.57046508789063,
#   'lng': 127.02467346191406,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '33p 남향,판상형,집상태굿,입주추천',
#   'agentNo': None,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T03:59:36.000Z',
#   'apartmentId': 22637,
#   'apartmentName': '텐즈힐2단지',
#   'buildingName': '206동',
#   'roomTypeId': 19225,
#   'grossAreaName': {'m2': 109, 'p': 32},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/22637/19225/e875ae5b098e4ada9221c18892e83553.png',
#   'userNo': 6025584,
#   'agentId': 6025584,
#   'agentName': '금맥공인중개사사무소',
#   'agentTel': '0327522442',
#   'agentUserName': '최효주',
#   'agentPhone': '01026335167',
#   'created_at': '2020-01-14 18:49:49',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/22637/19225/e875ae5b098e4ada9221c18892e83553.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 109, 'p': 32},
#   'isNew': True,
#   'sales': 135000},
#  {'itemId': 19899946,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.57046508789063,
#   'lng': 127.02467346191406,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '확장,시스템에어컨5대,단지안쪽뷰,입주',
#   'agentNo': None,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T03:59:30.000Z',
#   'apartmentId': 22637,
#   'apartmentName': '텐즈힐2단지',
#   'buildingName': '202동',
#   'roomTypeId': 19223,
#   'grossAreaName': {'m2': 106, 'p': 32},
#   'grossArea': {'m2': 106, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/22637/19223/80fcabaf6e8946df977fe51d15d4137a.png',
#   'userNo': 6025584,
#   'agentId': 6025584,
#   'agentName': '금맥공인중개사사무소',
#   'agentTel': '0327522442',
#   'agentUserName': '최효주',
#   'agentPhone': '01026335167',
#   'created_at': '2020-01-14 18:30:59',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/22637/19223/80fcabaf6e8946df977fe51d15d4137a.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 106, 'p': 32},
#   'isNew': True,
#   'sales': 140000},
#  {'itemId': 19899906,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.57046508789063,
#   'lng': 127.02467346191406,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '단지안쪽보는 조용한 라인,에어컨5대,입주',
#   'agentNo': None,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T03:59:28.000Z',
#   'apartmentId': 22637,
#   'apartmentName': '텐즈힐2단지',
#   'buildingName': '203동',
#   'roomTypeId': 19228,
#   'grossAreaName': {'m2': 159, 'p': 48},
#   'grossArea': {'m2': 159, 'p': 48},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 127, 'p': 38},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/22637/19228/e32d2febe9d94295aaf3d7e5f9d5743b.png',
#   'userNo': 6025584,
#   'agentId': 6025584,
#   'agentName': '금맥공인중개사사무소',
#   'agentTel': '0327522442',
#   'agentUserName': '최효주',
#   'agentPhone': '01026335167',
#   'created_at': '2020-01-14 18:30:00',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/22637/19228/e32d2febe9d94295aaf3d7e5f9d5743b.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 159, 'p': 48},
#   'isNew': True,
#   'sales': 140000},
#  {'itemId': 19899819,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '7',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '전세승계조건,필로티,조용한 라인,집상태굿',
#   'agentNo': None,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T03:59:25.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '116동',
#   'roomTypeId': 19813,
#   'grossAreaName': {'m2': '83A', 'p': '25A'},
#   'grossArea': {'m2': 83, 'p': 25},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19813/7ea5e91d1c3c4f40a89dc79960f9b556.png',
#   'userNo': 6025584,
#   'agentId': 6025584,
#   'agentName': '금맥공인중개사사무소',
#   'agentTel': '0327522442',
#   'agentUserName': '최효주',
#   'agentPhone': '01026335167',
#   'created_at': '2020-01-14 18:28:15',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19813/7ea5e91d1c3c4f40a89dc79960f9b556.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '83A', 'p': '25A'},
#   'isNew': True,
#   'sales': 113000},
#  {'itemId': 19899638,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '18',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '33p앞 뒤 뷰 예쁜 풀인테리어 된집,정남향,거주추천',
#   'agentNo': None,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T03:59:20.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '115동',
#   'roomTypeId': 149701,
#   'grossAreaName': {'m2': '109E', 'p': '32E'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149701/bd00eb036a1246c9b4f75ca91a53650a.png',
#   'userNo': 6025584,
#   'agentId': 6025584,
#   'agentName': '금맥공인중개사사무소',
#   'agentTel': '0327522442',
#   'agentUserName': '최효주',
#   'agentPhone': '01026335167',
#   'created_at': '2020-01-14 18:23:36',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149701/bd00eb036a1246c9b4f75ca91a53650a.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '109E', 'p': '32E'},
#   'isNew': True,
#   'sales': 150000},
#  {'itemId': 19899670,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '28',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '35p 멋진 시티뷰,전철역연결동,정남향,선호구조,에어컨유',
#   'agentNo': None,
#   'regDate': '2020-01-15',
#   'regTime': '2020-01-15T03:59:16.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '130동',
#   'roomTypeId': 149709,
#   'grossAreaName': {'m2': '116H', 'p': '35H'},
#   'grossArea': {'m2': 116, 'p': 35},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149709/d4b868a5c3da40e4870995cc279faf11.png',
#   'userNo': 6025584,
#   'agentId': 6025584,
#   'agentName': '금맥공인중개사사무소',
#   'agentTel': '0327522442',
#   'agentUserName': '최효주',
#   'agentPhone': '01026335167',
#   'created_at': '2020-01-14 18:24:28',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149709/d4b868a5c3da40e4870995cc279faf11.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '116H', 'p': '35H'},
#   'isNew': True,
#   'sales': 160000}]

# %%
item_df = pd.DataFrame(datas)
item_df.tail()
# Out:
#        itemId type exclusive_type  rent buildingFloor itemImages house_key  \
# 195  19899946   매매              1     0            25       None      None
# 196  19899906   매매              1     0            25       None      None
# 197  19899819   매매              1     0             7       None      None
# 198  19899638   매매              1     0            18       None      None
# 199  19899670   매매              1     0            28       None      None
#
#            lat         lng vr_status  ...   agentPhone           created_at  \
# 195  37.570465  127.024673      None  ...  01026335167  2020-01-14 18:30:59
# 196  37.570465  127.024673      None  ...  01026335167  2020-01-14 18:30:00
# 197  37.568861  127.027945      None  ...  01026335167  2020-01-14 18:28:15
# 198  37.565539  127.027069      None  ...  01026335167  2020-01-14 18:23:36
# 199  37.565539  127.027069      None  ...  01026335167  2020-01-14 18:24:28
#
#      real_type                                          itemImage  \
# 195        아파트  [https://ic.zigbang.com/ic/floorplan/22637/192...
# 196        아파트  [https://ic.zigbang.com/ic/floorplan/22637/192...
# 197        아파트  [https://ic.zigbang.com/ic/floorplan/24894/198...
# 198        아파트  [https://ic.zigbang.com/ic/floorplan/33613/149...
# 199        아파트  [https://ic.zigbang.com/ic/floorplan/33613/149...
#
#            sectionType  viewType groupedItemFloor           agreementAreaName  \
# 195  premium_recommend         1               고층        {'m2': 106, 'p': 32}
# 196  premium_recommend         1               고층        {'m2': 159, 'p': 48}
# 197  premium_recommend         1               저층   {'m2': '83A', 'p': '25A'}
# 198  premium_recommend         1               저층  {'m2': '109E', 'p': '32E'}
# 199  premium_recommend         1               고층  {'m2': '116H', 'p': '35H'}
#
#      isNew   sales
# 195   True  140000
# 196   True  140000
# 197   True  113000
# 198   True  150000
# 199   True  160000
#
# [5 rows x 39 columns]

# %%
len(item_df.columns)
# Out:
# 39

# %%
# panda option 설정
pd.options.display.max_columns = len(item_df.columns)

# %%
columns = [ "itemId", "buildingFloor", "groupedItemFloor", "grossArea", "lat", "lng", "sales", "itemTitle" ]
item_df = item_df[columns]

# %%
item_df["m2"] = item_df["grossArea"].apply(lambda data: data["m2"])
item_df["p"] = item_df["grossArea"].apply(lambda data: data["p"])
item_df.drop(columns=["grossArea"], inplace=True)

# %%
item_df.tail(1)
# Out:
#        itemId buildingFloor groupedItemFloor        lat         lng   sales  \
# 199  19899670            28               고층  37.565539  127.027069  160000
#
#                            itemTitle   m2   p
# 199  35p 멋진 시티뷰,전철역연결동,정남향,선호구조,에어컨유  116  35

# %% [markdown]
# #### 함수로 만들기
# - 동이름 -> 아파트 매물 데이터 프레임

# %%
def crawling_apt(addr):
    # 동이름 -> 위도,경도
    url = "https://apis.zigbang.com/search?q={}".format(addr)
    response = requests.get(url)
    data = response.json()["items"][0]
    lat, lng = data["lat"], data["lng"]
    
    # 위도,경도 -> geohash
    geohash = geohash2.encode(lat, lng, precision=5)
    
    # geohash -> ids
    url = "https://apis.zigbang.com/property/apartments/items?\
domain=zigbang&geohash={}\
&q=type=sales%7Cprice=0~-1%7CfloorArea=0~-1".format(geohash)
    response = requests.get(url)
    datas = response.json()["items"]
    ids = [data["itemId"] for data in datas]
    
    # ids -> items : 200개씩
    dfs = [] 
    for idx in range(0, len(ids), 200):
        start, end = idx, idx + 200
        ids_str = str(ids[start:end]).replace(" ", "")
        url = "https://apis.zigbang.com/property/apartments/items?\
        vritemIds={ids}&itemIds={ids}&citemIds={ids}".format(ids=ids_str)
        response = requests.get(url)
        datas = response.json()["items"]
        item_df = pd.DataFrame(datas)
        columns = [ "itemId", "buildingFloor", "groupedItemFloor", "grossArea", "lat", "lng", "sales", "itemTitle" ]
        item_df = item_df[columns]
        item_df["m2"] = item_df["grossArea"].apply(lambda data: data["m2"])
        item_df["p"] = item_df["grossArea"].apply(lambda data: data["p"])
        item_df.drop(columns=["grossArea"], inplace=True)
        dfs.append(item_df)
    result_df = pd.concat(dfs)
    result_df.reset_index(drop=True, inplace=True)
    return result_df

# %%
result = crawling_apt("성수동")
result.tail(2)
# Out:
#         itemId buildingFloor groupedItemFloor        lat         lng   sales  \
# 1582  19422824             7               중층  37.570465  127.024673  133000
# 1583  19430851            24               저층  37.562928  127.041072  100000
#
#                              itemTitle   m2   p
# 1582  33P 남향 높은3층 7층중3층 입주가능 갭5.8 투자최고  109  32
# 1583                    역세권4분,귀한매물입니다.  107  32

# %%
#도곡동에서 30층 이상되는 아파트에 고층 매물

# %%
items_df = crawling_apt("도곡동")
items_df.tail(2)
# Out:
#        itemId buildingFloor groupedItemFloor        lat         lng   sales  \
# 855  19481651            30               중층  37.501161  127.020831  300000
# 856  19451708            15               고층  37.491580  127.029970   81000
#
#                  itemTitle   m2   p
# 855       48.세안고매매 프리미엄럭셔리  159  48
# 856  대로변에 위치한 인기 주상복합 아파트    81  24

# %%
items_df = items_df[items_df["buildingFloor"].notnull()]
items_df.reset_index(drop =True,inplace=True)
items_df.tail(2)
# Out:
#        itemId buildingFloor groupedItemFloor        lat         lng   sales  \
# 851  19481651            30               중층  37.501161  127.020831  300000
# 852  19451708            15               고층  37.491580  127.029970   81000
#
#                  itemTitle   m2   p
# 851       48.세안고매매 프리미엄럭셔리  159  48
# 852  대로변에 위치한 인기 주상복합 아파트    81  24

# %%
items_df["buildingFloor"] = items_df["buildingFloor"].astype("int")
# Out:
# C:\Users\wjstk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
result_df = items_df[
    (items_df["buildingFloor"]>=30)
    & (items_df["groupedItemFloor"]=="고층")
]
len(result_df)
# Out:
# 135

# %%
result_df
# Out:
#        itemId  buildingFloor groupedItemFloor        lat         lng   sales  \
# 4    19077304             35               고층  37.501759  127.017936  250000
# 16   19906624             30               고층  37.493337  127.026873  243000
# 42   19809435             35               고층  37.501759  127.017936  244000
# 62   19828528             35               고층  37.503768  127.013323  198000
# 63   19830359             31               고층  37.503768  127.013323  265000
# ..        ...            ...              ...        ...         ...     ...
# 787  19425659             34               고층  37.501161  127.020831  195000
# 797  19863734             35               고층  37.503768  127.013323  215000
# 798  19858277             34               고층  37.501161  127.020831  245000
# 834  19637189             30               고층  37.501161  127.020831  300000
# 836  19155687             30               고층  37.501161  127.020831  260000
#
#                    itemTitle   m2   p
# 4         세안고 급매 로얄동 로얄층 추천   114  34
# 16   강남역초역세권입주2년차명품래미안채광전망최고  111  33
# 42           남향의 풀옵션 초급매건입니다  114  34
# 62         25 매매 BEST 매물입니다    84  25
# 63     34 매매 풀옵션 BEST 매물입니다   113  34
# ..                       ...  ...  ..
# 787      24.입주협의 세안고매매  풀에어컨   80  24
# 797  25p  집상태좋음 서원초 명문학원 9호선   84  25
# 798      입주협의 세언고매매가능 커뮤니티최고  116  35
# 834        48.귀한전세 판상형  입주협의  159  48
# 836          39.세안고매매  입주도가능  130  39
#
# [135 rows x 9 columns]

# %%
np.average(result_df["sales"])
# Out:
# 263696.2962962963

# %%
np.min(result_df["sales"])
# Out:
# 130000

# %%
# %%writefile zigbang.py
import pandas as pd
import requests
import geohash2

def crawling_apt(addr):
    # 동이름 -> 위도,경도
    url = "https://apis.zigbang.com/search?q={}".format(addr)
    response = requests.get(url)
    data = response.json()["items"][0]
    lat, lng = data["lat"], data["lng"]
    
    # 위도,경도 -> geohash
    geohash = geohash2.encode(lat, lng, precision=5)
    
    # geohash -> ids
    url = "https://apis.zigbang.com/property/apartments/items?\
domain=zigbang&geohash={}\
&q=type=sales%7Cprice=0~-1%7CfloorArea=0~-1".format(geohash)
    response = requests.get(url)
    datas = response.json()["items"]
    ids = [data["itemId"] for data in datas]
    
    # ids -> items : 200개씩
    dfs = [] 
    for idx in range(0, len(ids), 200):
        start, end = idx, idx + 200
        ids_str = str(ids[start:end]).replace(" ", "")
        url = "https://apis.zigbang.com/property/apartments/items?\
        vritemIds={ids}&itemIds={ids}&citemIds={ids}".format(ids=ids_str)
        response = requests.get(url)
        datas = response.json()["items"]
        item_df = pd.DataFrame(datas)
        columns = [ "itemId", "buildingFloor", "groupedItemFloor", "grossArea", "lat", "lng", "sales", "itemTitle" ]
        item_df = item_df[columns]
        item_df["m2"] = item_df["grossArea"].apply(lambda data: data["m2"])
        item_df["p"] = item_df["grossArea"].apply(lambda data: data["p"])
        item_df.drop(columns=["grossArea"], inplace=True)
        dfs.append(item_df)
    result_df = pd.concat(dfs)
    result_df.reset_index(drop=True, inplace=True)
    return result_df
# Out:
# Writing zigbang.py
